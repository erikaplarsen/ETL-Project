# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "WorldBank.csv"
data_df = pd.read_csv(csv_file)
data_df
# Out:
#                                         Country Name Country Code  \
# 0                                      Venezuela, RB          VEN
# 1                                      Venezuela, RB          VEN
# 2                                      Venezuela, RB          VEN
# 3                                      Venezuela, RB          VEN
# 4                                      Venezuela, RB          VEN
# 5                                      Venezuela, RB          VEN
# 6                                      Venezuela, RB          VEN
# 7                                      Venezuela, RB          VEN
# 8                                      Venezuela, RB          VEN
# 9                                      Venezuela, RB          VEN
# 10                                     Venezuela, RB          VEN
# 11                                     Venezuela, RB          VEN
# 12                                     Venezuela, RB          VEN
# ...

# %%
data_df.drop(columns=['Series Name'])
print(data_df)
# Out:
#                                         Country Name Country Code  \
# 0                                      Venezuela, RB          VEN
# 1                                      Venezuela, RB          VEN
# 2                                      Venezuela, RB          VEN
# 3                                      Venezuela, RB          VEN
# 4                                      Venezuela, RB          VEN
# 5                                      Venezuela, RB          VEN
# 6                                      Venezuela, RB          VEN
# 7                                      Venezuela, RB          VEN
# 8                                      Venezuela, RB          VEN
# 9                                      Venezuela, RB          VEN
# 10                                     Venezuela, RB          VEN
# 11                                     Venezuela, RB          VEN
# 12                                     Venezuela, RB          VEN
# ...
